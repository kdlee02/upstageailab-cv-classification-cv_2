# %%
from src.transforms.augmented import AugmentedTransform
from PIL import Image
import torch
import matplotlib.pyplot as plt
transform = AugmentedTransform()

img_path = './data/train/002f99746285dfdd.jpg'
image = Image.open(img_path).convert('RGB')

transformed_image = transform(image)
# device = transformed_image.device
mean = torch.tensor([0.485, 0.456, 0.406]).view(3,1,1)
std  = torch.tensor([0.229, 0.224, 0.225]).view(3,1,1)
img = transformed_image * std + mean
img = img.clamp(0,1)
img_np = img.permute(1,2,0).cpu().numpy()
plt.imshow(img_np)
plt.axis('off')
plt.show()

# %%
'RandomBackground' in  list(dir(aga))
# Out:
#   Cell In[39], line 6
#     'RandomLines',
#                   ^
# SyntaxError: incomplete input
